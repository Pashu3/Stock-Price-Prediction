# %%
#import necessary libraries
import pandas as pd
import numpy as np
pd.set_option("display.max_columns", None)
pd.set_option("display.width", 500)
import matplotlib.pyplot as plt
import tensorflow as tf
import datetime as dt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import warnings
warnings.filterwarnings("ignore")
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# %%
#read dataset
df = pd.read_csv("TSLA.csv")
df.head()
# Out:
#          Date       Open   High        Low      Close  Adj Close    Volume
# 0  2010-06-29  19.000000  25.00  17.540001  23.889999  23.889999  18766300
# 1  2010-06-30  25.790001  30.42  23.299999  23.830000  23.830000  17187100
# 2  2010-07-01  25.000000  25.92  20.270000  21.959999  21.959999   8218800
# 3  2010-07-02  23.000000  23.10  18.709999  19.200001  19.200001   5139800
# 4  2010-07-06  20.000000  20.00  15.830000  16.110001  16.110001   6866900

# %%
#check the head,tail,shape,dtype,quartiles
def check_df(dataframe,head=5):
  print("-------- Head -------")
  print(dataframe.head(head))
  print("------------ Tail ---------")
  print(dataframe.tail(head))
  print("------------ Shape ----------")
  print(dataframe.shape)
  print("--------- Types ---------")
  print(dataframe.dtypes)
  print("---------- NA ------------")
  print(dataframe.isnull().sum())
  print("-------------- Qurtiles -----------")
  print(dataframe.describe([0, 0.05, 0.50, 0.95, 0.99, 1]).T)


check_df(df)
# Out:
# -------- Head -------
#          Date       Open   High        Low      Close  Adj Close    Volume
# 0  2010-06-29  19.000000  25.00  17.540001  23.889999  23.889999  18766300
# 1  2010-06-30  25.790001  30.42  23.299999  23.830000  23.830000  17187100
# 2  2010-07-01  25.000000  25.92  20.270000  21.959999  21.959999   8218800
# 3  2010-07-02  23.000000  23.10  18.709999  19.200001  19.200001   5139800
# 4  2010-07-06  20.000000  20.00  15.830000  16.110001  16.110001   6866900
# ------------ Tail ---------
#             Date        Open        High         Low       Close   Adj Close    Volume
# 2411  2020-01-28  568.489990  576.809998  558.080017  566.900024  566.900024  11788500
# 2412  2020-01-29  575.690002  589.799988  567.429993  580.989990  580.989990  17801500
# 2413  2020-01-30  632.419983  650.880005  618.000000  640.809998  640.809998  29005700
# 2414  2020-01-31  640.000000  653.000000  632.520020  650.570007  650.570007  15719300
# 2415  2020-02-03  673.690002  786.140015  673.520020  780.000000  780.000000  47065000
# ------------ Shape ----------
# (2416, 7)
# --------- Types ---------
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object
# ---------- NA ------------
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# -------------- Qurtiles -----------
#             count          mean           std            min             0%             5%           50%           95%           99%          100%           max
# Open       2416.0  1.862711e+02  1.187402e+02      16.139999      16.139999      23.384999  2.130350e+02  3.519100e+02  4.235790e+02  6.736900e+02  6.736900e+02
# High       2416.0  1.895782e+02  1.208923e+02      16.629999      16.629999      24.022501  2.167450e+02  3.567500e+02  4.284705e+02  7.861400e+02  7.861400e+02
# Low        2416.0  1.829166e+02  1.168576e+02      14.980000      14.980000      22.867499  2.088700e+02  3.460250e+02  4.122865e+02  6.735200e+02  6.735200e+02
# Close      2416.0  1.864037e+02  1.191360e+02      15.800000      15.800000      23.565000  2.129600e+02  3.511675e+02  4.243455e+02  7.800000e+02  7.800000e+02
# Adj Close  2416.0  1.864037e+02  1.191360e+02      15.800000      15.800000      23.565000  2.129600e+02  3.511675e+02  4.243455e+02  7.800000e+02  7.800000e+02
# Volume     2416.0  5.572722e+06  4.987809e+06  118500.000000  118500.000000  633825.000000  4.578400e+06  1.476090e+07  2.459959e+07  4.706500e+07  4.706500e+07

# %%
#data preparation
df["Date"] = pd.to_datetime(df["Date"])
tesla_df = df[["Date", "Close"]]
tesla_df.index = tesla_df["Date"]
tesla_df.drop("Date", axis=1, inplace=True)
tesla_df.head()
# Out:
#                 Close
# Date
# 2010-06-29  23.889999
# 2010-06-30  23.830000
# 2010-07-01  21.959999
# 2010-07-02  19.200001
# 2010-07-06  16.110001

# %%
result_df = tesla_df.copy()
tesla_df = tesla_df.values
tesla_df = tesla_df.astype("float32")
tesla_df[0:5]
# Out:
# array([[23.89],
#        [23.83],
#        [21.96],
#        [19.2 ],
#        [16.11]], dtype=float32)

# %%
#Data Visualization
plt.figure(figsize=(12,6))
plt.plot(result_df["Close"], color="blue")
plt.ylabel("Stock Price")
plt.xlabel("Time")
plt.title("Tesla Stock Price")
plt.show()

# %%
#train and test split
def split_data(dataframe, test_size):
  position = int(round(len(dataframe) * (1-test_size)))
  train = dataframe[:position]
  test = dataframe[position:]
  return train, test, position


train, test, position = split_data(tesla_df, 0.20)
print("Train shape:", train.shape, " Test shape:", test.shape)
# Out:
# Train shape: (1933, 1)  Test shape: (483, 1)

# %%
#Encoding Scaling 
def encoding_scaling(train, test):
  scaler_train = MinMaxScaler(feature_range=(0,1))
  train = scaler_train.fit_transform(train)
  scaler_test = MinMaxScaler(feature_range=(0,1))
  test = scaler_test.fit_transform(test)
  return scaler_train, train, scaler_test, test


scaler_train, train, scaler_test, test = encoding_scaling(train, test)

# %%
#Create features
def create_features(data, lookback):
  X, Y = [], []
  for i in range(lookback, len(data)):
    X.append(data[i-lookback:i,0])
    Y.append(data[i,0])
  return np.array(X), np.array(Y)


lookback=20
X_train, y_train = create_features(train, lookback)
X_test, y_test = create_features(test, lookback)
print("X_train shape:", X_train.shape, " y_train shape:", y_train.shape, "\nX_test shape:", X_test.shape, " y_test shape: ", y_test.shape)


X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))
y_train = y_train.reshape(-1,1)
y_test = y_test.reshape(-1,1)
print("X_train shape:", X_train.shape, " y_train shape:", y_train.shape, "\nX_test shape:", X_test.shape, " y_test shape: ", y_test.shape)
# Out:
# X_train shape: (1913, 20)  y_train shape: (1913,)
# X_test shape: (463, 20)  y_test shape:  (463,)
# X_train shape: (1913, 1, 20)  y_train shape: (1913, 1)
# X_test shape: (463, 1, 20)  y_test shape:  (463, 1)

# %%
#Create and fit LSTM Model
def LSTM_create_and_fit_model(X_train,y_train, X_test, y_test, lookback=20, epochs=100, summary=True, fit=True):
  model = Sequential()
  model.add(LSTM(units=50, activation="relu", input_shape=(X_train.shape[1], lookback)))
  model.add(Dropout(0.2))
  model.add(Dense(1))
  model.compile(loss="mean_squared_error", optimizer="adam")
  callbacks = [EarlyStopping(monitor="val_loss", patience=3, verbose=1, mode="min"), 
              ModelCheckpoint(filepath="mymodel.h5", monitor="val_loss", mode="min", save_best_only=True, save_weights_only=False, verbose=1)]
  if summary:
    model.summary()
  if fit:
    history = model.fit(x=X_train, y=y_train, epochs=epochs, batch_size=20, 
                      validation_data=(X_test, y_test), callbacks=callbacks, shuffle=False)
  return model, history


model, history = LSTM_create_and_fit_model(X_train,y_train, X_test, y_test)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50)                14200
#
#  dropout (Dropout)           (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 14,251
# Trainable params: 14,251
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 94/96 [============================>.] - ETA: 0s - loss: 0.0079
# Epoch 1: val_loss improved from inf to 0.00399, saving model to mymodel.h5
# 96/96 [==============================] - 7s 17ms/step - loss: 0.0079 - val_loss: 0.0040
# Epoch 2/100
# 94/96 [============================>.] - ETA: 0s - loss: 0.0057
# Epoch 2: val_loss improved from 0.00399 to 0.00368, saving model to mymodel.h5
# 96/96 [==============================] - 1s 7ms/step - loss: 0.0059 - val_loss: 0.0037
# Epoch 3/100
# 83/96 [========================>.....] - ETA: 0s - loss: 0.0038
# Epoch 3: val_loss improved from 0.00368 to 0.00351, saving model to mymodel.h5
# 96/96 [==============================] - 1s 6ms/step - loss: 0.0054 - val_loss: 0.0035
# Epoch 4/100
# 93/96 [============================>.] - ETA: 0s - loss: 0.0040
# Epoch 4: val_loss improved from 0.00351 to 0.00345, saving model to mymodel.h5
# 96/96 [==============================] - 1s 7ms/step - loss: 0.0043 - val_loss: 0.0034
# Epoch 5/100
# 96/96 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 5: val_loss improved from 0.00345 to 0.00302, saving model to mymodel.h5
# 96/96 [==============================] - 1s 7ms/step - loss: 0.0046 - val_loss: 0.0030
# Epoch 6/100
# 81/96 [========================>.....] - ETA: 0s - loss: 0.0028
# Epoch 6: val_loss improved from 0.00302 to 0.00301, saving model to mymodel.h5
# 96/96 [==============================] - 1s 6ms/step - loss: 0.0040 - val_loss: 0.0030
# Epoch 7/100
# 89/96 [==========================>...] - ETA: 0s - loss: 0.0033
# Epoch 7: val_loss improved from 0.00301 to 0.00272, saving model to mymodel.h5
# 96/96 [==============================] - 1s 7ms/step - loss: 0.0039 - val_loss: 0.0027
# Epoch 8/100
# 87/96 [==========================>...] - ETA: 0s - loss: 0.0028
# Epoch 8: val_loss improved from 0.00272 to 0.00260, saving model to mymodel.h5
# 96/96 [==============================] - 1s 6ms/step - loss: 0.0037 - val_loss: 0.0026
# Epoch 9/100
# 83/96 [========================>.....] - ETA: 0s - loss: 0.0030
# Epoch 9: val_loss improved from 0.00260 to 0.00239, saving model to mymodel.h5
# 96/96 [==============================] - 1s 7ms/step - loss: 0.0041 - val_loss: 0.0024
# Epoch 10/100
# 83/96 [========================>.....] - ETA: 0s - loss: 0.0028
# Epoch 10: val_loss improved from 0.00239 to 0.00227, saving model to mymodel.h5
# 96/96 [==============================] - 1s 6ms/step - loss: 0.0036 - val_loss: 0.0023
# Epoch 11/100
# 83/96 [========================>.....] - ETA: 0s - loss: 0.0026
# Epoch 11: val_loss improved from 0.00227 to 0.00226, saving model to mymodel.h5
# 96/96 [==============================] - 1s 6ms/step - loss: 0.0037 - val_loss: 0.0023
# Epoch 12/100
# 85/96 [=========================>....] - ETA: 0s - loss: 0.0028
# Epoch 12: val_loss did not improve from 0.00226
# 96/96 [==============================] - 0s 4ms/step - loss: 0.0039 - val_loss: 0.0023
# Epoch 13/100
# 87/96 [==========================>...] - ETA: 0s - loss: 0.0028
# Epoch 13: val_loss improved from 0.00226 to 0.00220, saving model to mymodel.h5
# 96/96 [==============================] - 1s 6ms/step - loss: 0.0035 - val_loss: 0.0022
# Epoch 14/100
# 87/96 [==========================>...] - ETA: 0s - loss: 0.0030
# Epoch 14: val_loss improved from 0.00220 to 0.00215, saving model to mymodel.h5
# 96/96 [==============================] - 1s 6ms/step - loss: 0.0039 - val_loss: 0.0022
# Epoch 15/100
# 83/96 [========================>.....] - ETA: 0s - loss: 0.0029
# Epoch 15: val_loss did not improve from 0.00215
# 96/96 [==============================] - 0s 4ms/step - loss: 0.0040 - val_loss: 0.0032
# Epoch 16/100
# 88/96 [==========================>...] - ETA: 0s - loss: 0.0034
# Epoch 16: val_loss did not improve from 0.00215
# 96/96 [==============================] - 0s 4ms/step - loss: 0.0041 - val_loss: 0.0029
# Epoch 17/100
# 89/96 [==========================>...] - ETA: 0s - loss: 0.0033
# Epoch 17: val_loss did not improve from 0.00215
# 96/96 [==============================] - 0s 4ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 17: early stopping

# %%
#evaluate the model
def LSTM_model_evaluate(model):
  loss = model.evaluate(X_test, y_test, batch_size=20)
  print("Test Loss: %.2f" % (100 * loss))
  plt.figure(figsize=(10,5))
  plt.plot(history.history["loss"], color="r", label="Training Loss")
  plt.plot(history.history["val_loss"], color="b", label="Validation Loss")
  plt.legend(loc="upper right")
  plt.xlabel("Epoch", fontsize=16)
  plt.ylabel("Loss", fontsize=16)
  plt.ylim([0, max(plt.ylim())])
  plt.title("Training and Validation Loss", fontsize=16);


LSTM_model_evaluate(model)
# Out:
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0038
# Test Loss: 0.38

# %%
#Pedicting the values
def show_prediction(model, dataframe, X_train, X_test, y_train, y_test, lookback=20, plot=True):
  train_predict = model.predict(X_train)
  test_predict = model.predict(X_test)
  train_predict = scaler_train.inverse_transform(train_predict)
  test_predict = scaler_test.inverse_transform(test_predict) 
  y_train = scaler_train.inverse_transform(y_train)
  y_test = scaler_test.inverse_transform(y_test)
  RMSE_train = np.sqrt(mean_squared_error(y_train, train_predict))
  RMSE_test = np.sqrt(mean_squared_error(y_test, test_predict))
  print("---------- Loss ------------")
  print("RMSE Train: ", RMSE_train, "\nRMSE Test: ", RMSE_test)
  train_prediction_df = dataframe[lookback:position]
  train_prediction_df["Predicted"] = train_predict
  print("---------- Train Predictoion Head ------------")
  print(train_prediction_df.head())
  test_prediction_df = dataframe[position+lookback:]
  test_prediction_df["Predicted"] = test_predict
  print("---------- Test Predictoion Head ------------")
  print(test_prediction_df.head())
  if plot:
    plt.figure(figsize=(14,5))
    plt.plot(dataframe, label="Real Number of Passengers")
    plt.plot(train_prediction_df["Predicted"], color="blue", label="Train Predicted Stock Price")
    plt.plot(test_prediction_df["Predicted"], color="red", label="Test Predicted Stock Price")
    plt.title("Tesla Stock Price Prediction")
    plt.xlabel("Time")
    plt.ylabel("Stock Price")
    plt.legend()
    plt.show()


show_prediction(model, result_df, X_train, X_test, y_train, y_test)
# Out:
# 60/60 [==============================] - 0s 2ms/step
# 15/15 [==============================] - 0s 2ms/step
# ---------- Loss ------------
# RMSE Train:  17.049362
# RMSE Test:  37.131927
# ---------- Train Predictoion Head ------------
#                 Close  Predicted
# Date
# 2010-07-28  20.719999  38.177517
# 2010-07-29  20.350000  38.177517
# 2010-07-30  19.940001  38.177517
# 2010-08-02  20.920000  38.177517
# 2010-08-03  21.950001  38.177517
# ---------- Test Predictoion Head ------------
#                  Close   Predicted
# Date
# 2018-04-03  267.529999  330.027954
# 2018-04-04  286.940002  326.813782
# 2018-04-05  305.720001  327.468781
# 2018-04-06  299.299988  329.689362
# 2018-04-09  289.660004  331.397675
